# %%
print("1. 取出班次一的每一個時間")
import csv 
with open("./Data_Day002/example.csv",newline="",encoding='utf8') as csvfile: 
    text = csv.reader(csvfile) 
    for x in text:
        print(x[5])

print("2. 將班次一的每一個時間用一種資料型態保存")
import csv 
with open("./Data_Day002/example.csv",newline="",encoding='utf8') as csvfile: 
    thislist=[] 
    text = csv.reader(csvfile) 
    for x in text: 
        thislist.append(x[5])
first_order_list=list(thislist)
print(first_order_list)

print("3. 將班次一到五與其所有時間用一種資料型態個別保存")
import csv
with open("./Data_Day002/example.csv",newline='',encoding='utf8') as csvfile :
    text=csv.reader(csvfile) 
    thislist=list(text) #print(len(thislist)) #0 to 76 
    #the first row is equal to thistlist[0] #print(thislist[0][0]) #[0][0] to [76][16] 
for i in range(5 , 10):
    for j in range(len(thislist)): #print(thislist[0][0]) #[0][0] to [76][16] for i in range(5 , 10):
        print(thislist[j][i])
# Out:
# 1. 取出班次一的每一個時間
# 班次1
# 06:30
# 06:32
# 06:33
# 06:34
# 06:36
# 06:38
# 06:39
# 06:41
# 06:42
# 06:43
# 06:44
# 06:45
# 06:46
# 06:47
# 06:48
# 06:49
# 06:50
# 06:51
# 06:53
# 06:55
# 06:57
# 06:58
# 07:00
# 07:01
# 07:03
# 07:05
# 07:07
# 07:09
# 07:10
# 07:12
# 07:14
# 07:16
# 07:18
# 07:20
# 07:21
# 07:23
# 07:24
# 07:25
# 07:00
# 07:02
# 07:03
# 07:04
# 07:06
# 07:08
# 07:09
# 07:11
# 07:12
# 07:13
# 07:14
# 07:15
# 07:16
# 07:17
# 07:18
# 07:19
# 07:20
# 07:21
# 07:23
# 07:25
# 07:27
# 07:28
# 07:30
# 07:31
# 07:33
# 07:35
# 07:37
# 07:39
# 07:40
# 07:42
# 07:44
# 07:46
# 07:48
# 07:49
# 07:51
# 07:53
# 07:54
# 07:55
# 2. 將班次一的每一個時間用一種資料型態保存
# ...
